# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread(os.path.join('your_folder', 'FoxRemovalByPhotoPea.png'))
mask = cv2.imread(os.path.join('your_folder', 'FoxMaskByPhotopea.png'), 0)

imgNew = cv2.inpaint(img,mask,55,cv2.INPAINT_NS)

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB)),plt.title('mask of the missing pixels'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,2)
plt.imshow(mask,cmap='gray'),plt.title('The mask'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(imgNew,cv2.COLOR_BGR2RGB)),plt.title('image with missing pixels inpainted'),plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()
